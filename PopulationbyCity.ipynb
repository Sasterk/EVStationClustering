# %%
import pandas as pd
from pathlib import Path

# %%
population2=Path ('population_2022.csv')

# %%
population2_df= pd.read_csv(population2)
population2_df.head (200)
# Out:
#                GEO_ID                          NAME  \
# 0           Geography          Geographic Area Name
# 1    1600000US0103076          Auburn city, Alabama
# 2    1600000US0107000      Birmingham city, Alabama
# 3    1600000US0121184          Dothan city, Alabama
# 4    1600000US0135896          Hoover city, Alabama
# ..                ...                           ...
# 195  1600000US0877290       Thornton city, Colorado
# 196  1600000US0883835    Westminster city, Colorado
# 197  1600000US0908000  Bridgeport city, Connecticut
# 198  1600000US0918430     Danbury city, Connecticut
# 199  1600000US0937000    Hartford city, Connecticut
#
#                                   DP05_0001E  \
# 0    Estimate!!SEX AND AGE!!Total population
# 1                                      80009
# 2                                     196353
# 3                                      70524
# 4                                      92427
# ..                                       ...
# ...

# %%
population2_df.head
# Out:
# <bound method NDFrame.head of                GEO_ID                               NAME  \
# 0           Geography               Geographic Area Name
# 1    1600000US0103076               Auburn city, Alabama
# 2    1600000US0107000           Birmingham city, Alabama
# 3    1600000US0121184               Dothan city, Alabama
# 4    1600000US0135896               Hoover city, Alabama
# ..                ...                                ...
# 642  1600000US7210334    Caguas zona urbana, Puerto Rico
# 643  1600000US7214290  Carolina zona urbana, Puerto Rico
# 644  1600000US7232522  Guaynabo zona urbana, Puerto Rico
# 645  1600000US7263820     Ponce zona urbana, Puerto Rico
# 646  1600000US7276770  San Juan zona urbana, Puerto Rico
#
#                                   DP05_0001E  \
# 0    Estimate!!SEX AND AGE!!Total population
# 1                                      80009
# 2                                     196353
# 3                                      70524
# ...

# %%
population2_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 647 entries, 0 to 646
# Columns: 366 entries, GEO_ID to DP05_0091PM
# dtypes: object(366)
# memory usage: 1.8+ MB

# %%
population2_df.columns
# Out:
# Index(['GEO_ID', 'NAME', 'DP05_0001E', 'DP05_0001M', 'DP05_0002E',
#        'DP05_0002M', 'DP05_0003E', 'DP05_0003M', 'DP05_0004E', 'DP05_0004M',
#        ...
#        'DP05_0087PE', 'DP05_0087PM', 'DP05_0088PE', 'DP05_0088PM',
#        'DP05_0089PE', 'DP05_0089PM', 'DP05_0090PE', 'DP05_0090PM',
#        'DP05_0091PE', 'DP05_0091PM'],
#       dtype='object', length=366)

# %%
population2_df.drop (columns=['GEO_ID', 'DP05_0001M', 'DP05_0002E',
       'DP05_0002M', 'DP05_0003E', 'DP05_0003M', 'DP05_0004E', 'DP05_0004M',
       'DP05_0087PE', 'DP05_0087PM', 'DP05_0088PE', 'DP05_0088PM',
       'DP05_0089PE', 'DP05_0089PM', 'DP05_0090PE', 'DP05_0090PM',
       'DP05_0091PE', 'DP05_0091PM',
    
], inplace=True)

population2_df.head (200)
# Out:
#                              NAME                               DP05_0001E  \
# 0            Geographic Area Name  Estimate!!SEX AND AGE!!Total population
# 1            Auburn city, Alabama                                    80009
# 2        Birmingham city, Alabama                                   196353
# 3            Dothan city, Alabama                                    70524
# 4            Hoover city, Alabama                                    92427
# ..                            ...                                      ...
# 195       Thornton city, Colorado                                   143279
# 196    Westminster city, Colorado                                   114539
# 197  Bridgeport city, Connecticut                                   148365
# 198     Danbury city, Connecticut                                    86971
# 199    Hartford city, Connecticut                                   120682
#
#                                             DP05_0005E  \
# ...

# %%
population2_df.columns
# Out:
# Index(['NAME', 'DP05_0001E', 'DP05_0005E', 'DP05_0005M', 'DP05_0006E',
#        'DP05_0006M', 'DP05_0007E', 'DP05_0007M', 'DP05_0008E', 'DP05_0008M',
#        ...
#        'DP05_0082PE', 'DP05_0082PM', 'DP05_0083PE', 'DP05_0083PM',
#        'DP05_0084PE', 'DP05_0084PM', 'DP05_0085PE', 'DP05_0085PM',
#        'DP05_0086PE', 'DP05_0086PM'],
#       dtype='object', length=348)

# %%
population2_df.drop (columns=['DP05_0005E', 'DP05_0005M', 'DP05_0006E',
       'DP05_0006M', 'DP05_0007E', 'DP05_0007M', 'DP05_0008E', 'DP05_0008M',
       'DP05_0082PE', 'DP05_0082PM', 'DP05_0083PE', 'DP05_0083PM',
       'DP05_0084PE', 'DP05_0084PM', 'DP05_0085PE', 'DP05_0085PM',
       'DP05_0086PE', 'DP05_0086PM',
    
], inplace=True)

population2_df.head (200)
# Out:
#                              NAME                               DP05_0001E  \
# 0            Geographic Area Name  Estimate!!SEX AND AGE!!Total population
# 1            Auburn city, Alabama                                    80009
# 2        Birmingham city, Alabama                                   196353
# 3            Dothan city, Alabama                                    70524
# 4            Hoover city, Alabama                                    92427
# ..                            ...                                      ...
# 195       Thornton city, Colorado                                   143279
# 196    Westminster city, Colorado                                   114539
# 197  Bridgeport city, Connecticut                                   148365
# 198     Danbury city, Connecticut                                    86971
# 199    Hartford city, Connecticut                                   120682
#
#                                             DP05_0009E  \
# ...

# %%
population2_df.columns
# Out:
# Index(['NAME', 'DP05_0001E', 'DP05_0009E', 'DP05_0009M', 'DP05_0010E',
#        'DP05_0010M', 'DP05_0011E', 'DP05_0011M', 'DP05_0012E', 'DP05_0012M',
#        ...
#        'DP05_0077PE', 'DP05_0077PM', 'DP05_0078PE', 'DP05_0078PM',
#        'DP05_0079PE', 'DP05_0079PM', 'DP05_0080PE', 'DP05_0080PM',
#        'DP05_0081PE', 'DP05_0081PM'],
#       dtype='object', length=330)

# %%
population2_df.drop (columns=['DP05_0009E', 'DP05_0009M', 'DP05_0010E',
       'DP05_0010M', 'DP05_0011E', 'DP05_0011M', 'DP05_0012E', 'DP05_0012M',
       'DP05_0077PE', 'DP05_0077PM', 'DP05_0078PE', 'DP05_0078PM',
       'DP05_0079PE', 'DP05_0079PM', 'DP05_0080PE', 'DP05_0080PM',
       'DP05_0081PE', 'DP05_0081PM',
    
], inplace=True)

population2_df.head (200)
# Out:
#                              NAME                               DP05_0001E  \
# 0            Geographic Area Name  Estimate!!SEX AND AGE!!Total population
# 1            Auburn city, Alabama                                    80009
# 2        Birmingham city, Alabama                                   196353
# 3            Dothan city, Alabama                                    70524
# 4            Hoover city, Alabama                                    92427
# ..                            ...                                      ...
# 195       Thornton city, Colorado                                   143279
# 196    Westminster city, Colorado                                   114539
# 197  Bridgeport city, Connecticut                                   148365
# 198     Danbury city, Connecticut                                    86971
# 199    Hartford city, Connecticut                                   120682
#
#                                             DP05_0013E  \
# ...

# %%
population2_df.columns
# Out:
# Index(['NAME', 'DP05_0001E', 'DP05_0013E', 'DP05_0013M', 'DP05_0014E',
#        'DP05_0014M', 'DP05_0015E', 'DP05_0015M', 'DP05_0016E', 'DP05_0016M',
#        ...
#        'DP05_0072PE', 'DP05_0072PM', 'DP05_0073PE', 'DP05_0073PM',
#        'DP05_0074PE', 'DP05_0074PM', 'DP05_0075PE', 'DP05_0075PM',
#        'DP05_0076PE', 'DP05_0076PM'],
#       dtype='object', length=312)

# %%
population2_df.drop (columns=['DP05_0013E', 'DP05_0013M', 'DP05_0014E',
       'DP05_0014M', 'DP05_0015E', 'DP05_0015M', 'DP05_0016E', 'DP05_0016M',
       'DP05_0072PE', 'DP05_0072PM', 'DP05_0073PE', 'DP05_0073PM',
       'DP05_0074PE', 'DP05_0074PM', 'DP05_0075PE', 'DP05_0075PM',
       'DP05_0076PE', 'DP05_0076PM'
    
], inplace=True)

population2_df.head (200)
# Out:
#                              NAME                               DP05_0001E  \
# 0            Geographic Area Name  Estimate!!SEX AND AGE!!Total population
# 1            Auburn city, Alabama                                    80009
# 2        Birmingham city, Alabama                                   196353
# 3            Dothan city, Alabama                                    70524
# 4            Hoover city, Alabama                                    92427
# ..                            ...                                      ...
# 195       Thornton city, Colorado                                   143279
# 196    Westminster city, Colorado                                   114539
# 197  Bridgeport city, Connecticut                                   148365
# 198     Danbury city, Connecticut                                    86971
# 199    Hartford city, Connecticut                                   120682
#
#                                             DP05_0017E  \
# ...

# %%
population2_df.columns
# Out:
# Index(['NAME', 'DP05_0001E', 'DP05_0017E', 'DP05_0017M', 'DP05_0018E',
#        'DP05_0018M', 'DP05_0019E', 'DP05_0019M', 'DP05_0020E', 'DP05_0020M',
#        ...
#        'DP05_0067PE', 'DP05_0067PM', 'DP05_0068PE', 'DP05_0068PM',
#        'DP05_0069PE', 'DP05_0069PM', 'DP05_0070PE', 'DP05_0070PM',
#        'DP05_0071PE', 'DP05_0071PM'],
#       dtype='object', length=294)

# %%
population2_df.drop (columns=['DP05_0017E', 'DP05_0017M', 'DP05_0018E',
       'DP05_0018M', 'DP05_0019E', 'DP05_0019M', 'DP05_0020E', 'DP05_0020M',
       'DP05_0067PE', 'DP05_0067PM', 'DP05_0068PE', 'DP05_0068PM',
       'DP05_0069PE', 'DP05_0069PM', 'DP05_0070PE', 'DP05_0070PM',
       'DP05_0071PE', 'DP05_0071PM'
    
], inplace=True)

population2_df.head (200)
# Out:
#                              NAME                               DP05_0001E  \
# 0            Geographic Area Name  Estimate!!SEX AND AGE!!Total population
# 1            Auburn city, Alabama                                    80009
# 2        Birmingham city, Alabama                                   196353
# 3            Dothan city, Alabama                                    70524
# 4            Hoover city, Alabama                                    92427
# ..                            ...                                      ...
# 195       Thornton city, Colorado                                   143279
# 196    Westminster city, Colorado                                   114539
# 197  Bridgeport city, Connecticut                                   148365
# 198     Danbury city, Connecticut                                    86971
# 199    Hartford city, Connecticut                                   120682
#
#                                             DP05_0021E  \
# ...

# %%
population2_df.columns
# Out:
# Index(['NAME', 'DP05_0001E', 'DP05_0021E', 'DP05_0021M', 'DP05_0022E',
#        'DP05_0022M', 'DP05_0023E', 'DP05_0023M', 'DP05_0024E', 'DP05_0024M',
#        ...
#        'DP05_0062PE', 'DP05_0062PM', 'DP05_0063PE', 'DP05_0063PM',
#        'DP05_0064PE', 'DP05_0064PM', 'DP05_0065PE', 'DP05_0065PM',
#        'DP05_0066PE', 'DP05_0066PM'],
#       dtype='object', length=276)

# %%
population2_df.drop (columns=['DP05_0021E', 'DP05_0021M', 'DP05_0022E',
       'DP05_0022M', 'DP05_0023E', 'DP05_0023M', 'DP05_0024E', 'DP05_0024M',
       'DP05_0062PE', 'DP05_0062PM', 'DP05_0063PE', 'DP05_0063PM',
       'DP05_0064PE', 'DP05_0064PM', 'DP05_0065PE', 'DP05_0065PM',
       'DP05_0066PE', 'DP05_0066PM'
    
], inplace=True)

population2_df.head (200)
# Out:
#                              NAME                               DP05_0001E  \
# 0            Geographic Area Name  Estimate!!SEX AND AGE!!Total population
# 1            Auburn city, Alabama                                    80009
# 2        Birmingham city, Alabama                                   196353
# 3            Dothan city, Alabama                                    70524
# 4            Hoover city, Alabama                                    92427
# ..                            ...                                      ...
# 195       Thornton city, Colorado                                   143279
# 196    Westminster city, Colorado                                   114539
# 197  Bridgeport city, Connecticut                                   148365
# 198     Danbury city, Connecticut                                    86971
# 199    Hartford city, Connecticut                                   120682
#
#                                             DP05_0025E  \
# ...

# %%
population2_df.columns
# Out:
# Index(['NAME', 'DP05_0001E', 'DP05_0025E', 'DP05_0025M', 'DP05_0026E',
#        'DP05_0026M', 'DP05_0027E', 'DP05_0027M', 'DP05_0028E', 'DP05_0028M',
#        ...
#        'DP05_0057PE', 'DP05_0057PM', 'DP05_0058PE', 'DP05_0058PM',
#        'DP05_0059PE', 'DP05_0059PM', 'DP05_0060PE', 'DP05_0060PM',
#        'DP05_0061PE', 'DP05_0061PM'],
#       dtype='object', length=258)

# %%
population2_df.drop (columns=['DP05_0025E', 'DP05_0025M', 'DP05_0026E',
       'DP05_0026M', 'DP05_0027E', 'DP05_0027M', 'DP05_0028E', 'DP05_0028M',
       'DP05_0057PE', 'DP05_0057PM', 'DP05_0058PE', 'DP05_0058PM',
       'DP05_0059PE', 'DP05_0059PM', 'DP05_0060PE', 'DP05_0060PM',
       'DP05_0061PE', 'DP05_0061PM'
    
], inplace=True)

population2_df.head (200)
# Out:
#                              NAME                               DP05_0001E  \
# 0            Geographic Area Name  Estimate!!SEX AND AGE!!Total population
# 1            Auburn city, Alabama                                    80009
# 2        Birmingham city, Alabama                                   196353
# 3            Dothan city, Alabama                                    70524
# 4            Hoover city, Alabama                                    92427
# ..                            ...                                      ...
# 195       Thornton city, Colorado                                   143279
# 196    Westminster city, Colorado                                   114539
# 197  Bridgeport city, Connecticut                                   148365
# 198     Danbury city, Connecticut                                    86971
# 199    Hartford city, Connecticut                                   120682
#
#                                             DP05_0029E  \
# ...

# %%
population2_df.columns
# Out:
# Index(['NAME', 'DP05_0001E', 'DP05_0029E', 'DP05_0029M', 'DP05_0030E',
#        'DP05_0030M', 'DP05_0031E', 'DP05_0031M', 'DP05_0032E', 'DP05_0032M',
#        ...
#        'DP05_0052PE', 'DP05_0052PM', 'DP05_0053PE', 'DP05_0053PM',
#        'DP05_0054PE', 'DP05_0054PM', 'DP05_0055PE', 'DP05_0055PM',
#        'DP05_0056PE', 'DP05_0056PM'],
#       dtype='object', length=240)

# %%
population2_df.drop (columns=['DP05_0029E', 'DP05_0029M', 'DP05_0030E',
       'DP05_0030M', 'DP05_0031E', 'DP05_0031M', 'DP05_0032E', 'DP05_0032M',
       'DP05_0052PE', 'DP05_0052PM', 'DP05_0053PE', 'DP05_0053PM',
       'DP05_0054PE', 'DP05_0054PM', 'DP05_0055PE', 'DP05_0055PM',
       'DP05_0056PE', 'DP05_0056PM'
    
], inplace=True)

population2_df.head (200)
# Out:
#                              NAME                               DP05_0001E  \
# 0            Geographic Area Name  Estimate!!SEX AND AGE!!Total population
# 1            Auburn city, Alabama                                    80009
# 2        Birmingham city, Alabama                                   196353
# 3            Dothan city, Alabama                                    70524
# 4            Hoover city, Alabama                                    92427
# ..                            ...                                      ...
# 195       Thornton city, Colorado                                   143279
# 196    Westminster city, Colorado                                   114539
# 197  Bridgeport city, Connecticut                                   148365
# 198     Danbury city, Connecticut                                    86971
# 199    Hartford city, Connecticut                                   120682
#
#                            DP05_0033E  \
# ...

# %%
population2_df.columns
# Out:
# Index(['NAME', 'DP05_0001E', 'DP05_0033E', 'DP05_0033M', 'DP05_0034E',
#        'DP05_0034M', 'DP05_0035E', 'DP05_0035M', 'DP05_0036E', 'DP05_0036M',
#        ...
#        'DP05_0047PE', 'DP05_0047PM', 'DP05_0048PE', 'DP05_0048PM',
#        'DP05_0049PE', 'DP05_0049PM', 'DP05_0050PE', 'DP05_0050PM',
#        'DP05_0051PE', 'DP05_0051PM'],
#       dtype='object', length=222)

# %%
population2_df.drop (columns=['DP05_0033E', 'DP05_0033M', 'DP05_0034E',
       'DP05_0034M', 'DP05_0035E', 'DP05_0035M', 'DP05_0036E', 'DP05_0036M',
       'DP05_0047PE', 'DP05_0047PM', 'DP05_0048PE', 'DP05_0048PM',
       'DP05_0049PE', 'DP05_0049PM', 'DP05_0050PE', 'DP05_0050PM',
       'DP05_0051PE', 'DP05_0051PM'
    
], inplace=True)

population2_df.head (200)
# Out:
#                              NAME                               DP05_0001E  \
# 0            Geographic Area Name  Estimate!!SEX AND AGE!!Total population
# 1            Auburn city, Alabama                                    80009
# 2        Birmingham city, Alabama                                   196353
# 3            Dothan city, Alabama                                    70524
# 4            Hoover city, Alabama                                    92427
# ..                            ...                                      ...
# 195       Thornton city, Colorado                                   143279
# 196    Westminster city, Colorado                                   114539
# 197  Bridgeport city, Connecticut                                   148365
# 198     Danbury city, Connecticut                                    86971
# 199    Hartford city, Connecticut                                   120682
#
#                                             DP05_0037E  \
# ...

# %%
population2_df.columns
# Out:
# Index(['NAME', 'DP05_0001E', 'DP05_0037E', 'DP05_0037M', 'DP05_0038E',
#        'DP05_0038M', 'DP05_0039E', 'DP05_0039M', 'DP05_0040E', 'DP05_0040M',
#        ...
#        'DP05_0042PE', 'DP05_0042PM', 'DP05_0043PE', 'DP05_0043PM',
#        'DP05_0044PE', 'DP05_0044PM', 'DP05_0045PE', 'DP05_0045PM',
#        'DP05_0046PE', 'DP05_0046PM'],
#       dtype='object', length=204)

# %%
population2_df.drop (columns=['DP05_0037E', 'DP05_0037M', 'DP05_0038E',
       'DP05_0038M', 'DP05_0039E', 'DP05_0039M', 'DP05_0040E', 'DP05_0040M',
       'DP05_0042PE', 'DP05_0042PM', 'DP05_0043PE', 'DP05_0043PM',
       'DP05_0044PE', 'DP05_0044PM', 'DP05_0045PE', 'DP05_0045PM',
       'DP05_0046PE', 'DP05_0046PM'
    
], inplace=True)

population2_df.head (200)
# Out:
#                              NAME                               DP05_0001E  \
# 0            Geographic Area Name  Estimate!!SEX AND AGE!!Total population
# 1            Auburn city, Alabama                                    80009
# 2        Birmingham city, Alabama                                   196353
# 3            Dothan city, Alabama                                    70524
# 4            Hoover city, Alabama                                    92427
# ..                            ...                                      ...
# 195       Thornton city, Colorado                                   143279
# 196    Westminster city, Colorado                                   114539
# 197  Bridgeport city, Connecticut                                   148365
# 198     Danbury city, Connecticut                                    86971
# 199    Hartford city, Connecticut                                   120682
#
#                                             DP05_0041E  \
# ...

# %%
population2_df.columns
# Out:
# Index(['NAME', 'DP05_0001E', 'DP05_0041E', 'DP05_0041M', 'DP05_0042E',
#        'DP05_0042M', 'DP05_0043E', 'DP05_0043M', 'DP05_0044E', 'DP05_0044M',
#        ...
#        'DP05_0037PE', 'DP05_0037PM', 'DP05_0038PE', 'DP05_0038PM',
#        'DP05_0039PE', 'DP05_0039PM', 'DP05_0040PE', 'DP05_0040PM',
#        'DP05_0041PE', 'DP05_0041PM'],
#       dtype='object', length=186)

# %%
population2_df.drop (columns=['DP05_0041E', 'DP05_0041M', 'DP05_0042E',
       'DP05_0042M', 'DP05_0043E', 'DP05_0043M', 'DP05_0044E', 'DP05_0044M',
       'DP05_0037PE', 'DP05_0037PM', 'DP05_0038PE', 'DP05_0038PM',
       'DP05_0039PE', 'DP05_0039PM', 'DP05_0040PE', 'DP05_0040PM',
       'DP05_0041PE', 'DP05_0041PM']
    
, inplace=True)

population2_df.head (200)
# Out:
#                              NAME                               DP05_0001E  \
# 0            Geographic Area Name  Estimate!!SEX AND AGE!!Total population
# 1            Auburn city, Alabama                                    80009
# 2        Birmingham city, Alabama                                   196353
# 3            Dothan city, Alabama                                    70524
# 4            Hoover city, Alabama                                    92427
# ..                            ...                                      ...
# 195       Thornton city, Colorado                                   143279
# 196    Westminster city, Colorado                                   114539
# 197  Bridgeport city, Connecticut                                   148365
# 198     Danbury city, Connecticut                                    86971
# 199    Hartford city, Connecticut                                   120682
#
#                                             DP05_0045E  \
# ...

# %%
population2_df.columns
# Out:
# Index(['NAME', 'DP05_0001E', 'DP05_0045E', 'DP05_0045M', 'DP05_0046E',
#        'DP05_0046M', 'DP05_0047E', 'DP05_0047M', 'DP05_0048E', 'DP05_0048M',
#        ...
#        'DP05_0032PE', 'DP05_0032PM', 'DP05_0033PE', 'DP05_0033PM',
#        'DP05_0034PE', 'DP05_0034PM', 'DP05_0035PE', 'DP05_0035PM',
#        'DP05_0036PE', 'DP05_0036PM'],
#       dtype='object', length=168)

# %%
population2_df.drop (columns=['DP05_0045E', 'DP05_0045M', 'DP05_0046E',
       'DP05_0046M', 'DP05_0047E', 'DP05_0047M', 'DP05_0048E', 'DP05_0048M',
       'DP05_0032PE', 'DP05_0032PM', 'DP05_0033PE', 'DP05_0033PM',
       'DP05_0034PE', 'DP05_0034PM', 'DP05_0035PE', 'DP05_0035PM',
       'DP05_0036PE', 'DP05_0036PM']
    
, inplace=True)

population2_df.head (200)
# Out:
#                              NAME                               DP05_0001E  \
# 0            Geographic Area Name  Estimate!!SEX AND AGE!!Total population
# 1            Auburn city, Alabama                                    80009
# 2        Birmingham city, Alabama                                   196353
# 3            Dothan city, Alabama                                    70524
# 4            Hoover city, Alabama                                    92427
# ..                            ...                                      ...
# 195       Thornton city, Colorado                                   143279
# 196    Westminster city, Colorado                                   114539
# 197  Bridgeport city, Connecticut                                   148365
# 198     Danbury city, Connecticut                                    86971
# 199    Hartford city, Connecticut                                   120682
#
#                                             DP05_0049E  \
# ...

# %%
population2_df.columns
# Out:
# Index(['NAME', 'DP05_0001E', 'DP05_0049E', 'DP05_0049M', 'DP05_0050E',
#        'DP05_0050M', 'DP05_0051E', 'DP05_0051M', 'DP05_0052E', 'DP05_0052M',
#        ...
#        'DP05_0027PE', 'DP05_0027PM', 'DP05_0028PE', 'DP05_0028PM',
#        'DP05_0029PE', 'DP05_0029PM', 'DP05_0030PE', 'DP05_0030PM',
#        'DP05_0031PE', 'DP05_0031PM'],
#       dtype='object', length=150)

# %%
population2_df.drop (columns=['DP05_0049E', 'DP05_0049M', 'DP05_0050E',
       'DP05_0050M', 'DP05_0051E', 'DP05_0051M', 'DP05_0052E', 'DP05_0052M',
       'DP05_0027PE', 'DP05_0027PM', 'DP05_0028PE', 'DP05_0028PM',
       'DP05_0029PE', 'DP05_0029PM', 'DP05_0030PE', 'DP05_0030PM',
       'DP05_0031PE', 'DP05_0031PM']
    
, inplace=True)

population2_df.head (200)
# Out:
#                              NAME                               DP05_0001E  \
# 0            Geographic Area Name  Estimate!!SEX AND AGE!!Total population
# 1            Auburn city, Alabama                                    80009
# 2        Birmingham city, Alabama                                   196353
# 3            Dothan city, Alabama                                    70524
# 4            Hoover city, Alabama                                    92427
# ..                            ...                                      ...
# 195       Thornton city, Colorado                                   143279
# 196    Westminster city, Colorado                                   114539
# 197  Bridgeport city, Connecticut                                   148365
# 198     Danbury city, Connecticut                                    86971
# 199    Hartford city, Connecticut                                   120682
#
#                                             DP05_0053E  \
# ...

# %%
population2_df.columns
# Out:
# Index(['NAME', 'DP05_0001E', 'DP05_0053E', 'DP05_0053M', 'DP05_0054E',
#        'DP05_0054M', 'DP05_0055E', 'DP05_0055M', 'DP05_0056E', 'DP05_0056M',
#        ...
#        'DP05_0022PE', 'DP05_0022PM', 'DP05_0023PE', 'DP05_0023PM',
#        'DP05_0024PE', 'DP05_0024PM', 'DP05_0025PE', 'DP05_0025PM',
#        'DP05_0026PE', 'DP05_0026PM'],
#       dtype='object', length=132)

# %%
population2_df.drop (columns=['DP05_0053E', 'DP05_0053M', 'DP05_0054E',
       'DP05_0054M', 'DP05_0055E', 'DP05_0055M', 'DP05_0056E', 'DP05_0056M',         
                              
       'DP05_0022PE', 'DP05_0022PM', 'DP05_0023PE', 'DP05_0023PM',
       'DP05_0024PE', 'DP05_0024PM', 'DP05_0025PE', 'DP05_0025PM',
       'DP05_0026PE', 'DP05_0026PM']
    
, inplace=True)

population2_df.head (200)
# Out:
#                              NAME                               DP05_0001E  \
# 0            Geographic Area Name  Estimate!!SEX AND AGE!!Total population
# 1            Auburn city, Alabama                                    80009
# 2        Birmingham city, Alabama                                   196353
# 3            Dothan city, Alabama                                    70524
# 4            Hoover city, Alabama                                    92427
# ..                            ...                                      ...
# 195       Thornton city, Colorado                                   143279
# 196    Westminster city, Colorado                                   114539
# 197  Bridgeport city, Connecticut                                   148365
# 198     Danbury city, Connecticut                                    86971
# 199    Hartford city, Connecticut                                   120682
#
#                                             DP05_0057E  \
# ...

# %%
population2_df.columns
# Out:
# Index(['NAME', 'DP05_0001E', 'DP05_0057E', 'DP05_0057M', 'DP05_0058E',
#        'DP05_0058M', 'DP05_0059E', 'DP05_0059M', 'DP05_0060E', 'DP05_0060M',
#        ...
#        'DP05_0017PE', 'DP05_0017PM', 'DP05_0018PE', 'DP05_0018PM',
#        'DP05_0019PE', 'DP05_0019PM', 'DP05_0020PE', 'DP05_0020PM',
#        'DP05_0021PE', 'DP05_0021PM'],
#       dtype='object', length=114)

# %%
population2_df.drop (columns=['DP05_0057E', 'DP05_0057M', 'DP05_0058E',
       'DP05_0058M', 'DP05_0059E', 'DP05_0059M', 'DP05_0060E', 'DP05_0060M',
       'DP05_0017PE', 'DP05_0017PM', 'DP05_0018PE', 'DP05_0018PM',
       'DP05_0019PE', 'DP05_0019PM', 'DP05_0020PE', 'DP05_0020PM',
       'DP05_0021PE', 'DP05_0021PM']
    
, inplace=True)

population2_df.head (200)
# Out:
#                              NAME                               DP05_0001E  \
# 0            Geographic Area Name  Estimate!!SEX AND AGE!!Total population
# 1            Auburn city, Alabama                                    80009
# 2        Birmingham city, Alabama                                   196353
# 3            Dothan city, Alabama                                    70524
# 4            Hoover city, Alabama                                    92427
# ..                            ...                                      ...
# 195       Thornton city, Colorado                                   143279
# 196    Westminster city, Colorado                                   114539
# 197  Bridgeport city, Connecticut                                   148365
# 198     Danbury city, Connecticut                                    86971
# 199    Hartford city, Connecticut                                   120682
#
#                                             DP05_0061E  \
# ...

# %%
population2_df.columns
# Out:
# Index(['NAME', 'DP05_0001E', 'DP05_0061E', 'DP05_0061M', 'DP05_0062E',
#        'DP05_0062M', 'DP05_0063E', 'DP05_0063M', 'DP05_0064E', 'DP05_0064M',
#        'DP05_0065E', 'DP05_0065M', 'DP05_0066E', 'DP05_0066M', 'DP05_0067E',
#        'DP05_0067M', 'DP05_0068E', 'DP05_0068M', 'DP05_0069E', 'DP05_0069M',
#        'DP05_0070E', 'DP05_0070M', 'DP05_0071E', 'DP05_0071M', 'DP05_0072E',
#        'DP05_0072M', 'DP05_0073E', 'DP05_0073M', 'DP05_0074E', 'DP05_0074M',
#        'DP05_0075E', 'DP05_0075M', 'DP05_0076E', 'DP05_0076M', 'DP05_0077E',
#        'DP05_0077M', 'DP05_0078E', 'DP05_0078M', 'DP05_0079E', 'DP05_0079M',
#        'DP05_0080E', 'DP05_0080M', 'DP05_0081E', 'DP05_0081M', 'DP05_0082E',
#        'DP05_0082M', 'DP05_0083E', 'DP05_0083M', 'DP05_0084E', 'DP05_0084M',
#        'DP05_0085E', 'DP05_0085M', 'DP05_0086E', 'DP05_0086M', 'DP05_0087E',
#        'DP05_0087M', 'DP05_0088E', 'DP05_0088M', 'DP05_0089E', 'DP05_0089M',
# ...

# %%
population2_df.drop (columns=['DP05_0061E', 'DP05_0061M', 'DP05_0062E',
       'DP05_0062M', 'DP05_0063E', 'DP05_0063M', 'DP05_0064E', 'DP05_0064M',
       'DP05_0065E', 'DP05_0065M', 'DP05_0066E', 'DP05_0066M', 'DP05_0067E',
       'DP05_0067M', 'DP05_0068E', 'DP05_0068M', 'DP05_0069E', 'DP05_0069M',
       'DP05_0070E', 'DP05_0070M', 'DP05_0071E', 'DP05_0071M', 'DP05_0072E',
       'DP05_0072M', 'DP05_0073E', 'DP05_0073M', 'DP05_0074E', 'DP05_0074M',
       'DP05_0075E', 'DP05_0075M', 'DP05_0076E', 'DP05_0076M', 'DP05_0077E',
       'DP05_0077M', 'DP05_0078E', 'DP05_0078M', 'DP05_0079E', 'DP05_0079M',
       'DP05_0080E', 'DP05_0080M', 'DP05_0081E', 'DP05_0081M', 'DP05_0082E',
       'DP05_0082M', 'DP05_0083E', 'DP05_0083M', 'DP05_0084E', 'DP05_0084M',
       'DP05_0085E', 'DP05_0085M', 'DP05_0086E', 'DP05_0086M', 'DP05_0087E',
       'DP05_0087M', 'DP05_0088E', 'DP05_0088M', 'DP05_0089E', 'DP05_0089M',
       'DP05_0090E', 'DP05_0090M', 'DP05_0091E', 'DP05_0091M', 'DP05_0001PE',
       'DP05_0001PM', 'DP05_0002PE', 'DP05_0002PM', 'DP05_0003PE',
       'DP05_0003PM', 'DP05_0004PE', 'DP05_0004PM', 'DP05_0005PE',
       'DP05_0005PM', 'DP05_0006PE', 'DP05_0006PM', 'DP05_0007PE',
       'DP05_0007PM', 'DP05_0008PE', 'DP05_0008PM', 'DP05_0009PE',
       'DP05_0009PM', 'DP05_0010PE', 'DP05_0010PM', 'DP05_0011PE',
       'DP05_0011PM', 'DP05_0012PE', 'DP05_0012PM', 'DP05_0013PE',
       'DP05_0013PM', 'DP05_0014PE', 'DP05_0014PM', 'DP05_0015PE',
       'DP05_0015PM', 'DP05_0016PE', 'DP05_0016PM']
    
, inplace=True)

population2_df.head (200)
# Out:
#                              NAME                               DP05_0001E
# 0            Geographic Area Name  Estimate!!SEX AND AGE!!Total population
# 1            Auburn city, Alabama                                    80009
# 2        Birmingham city, Alabama                                   196353
# 3            Dothan city, Alabama                                    70524
# 4            Hoover city, Alabama                                    92427
# ..                            ...                                      ...
# 195       Thornton city, Colorado                                   143279
# 196    Westminster city, Colorado                                   114539
# 197  Bridgeport city, Connecticut                                   148365
# 198     Danbury city, Connecticut                                    86971
# 199    Hartford city, Connecticut                                   120682
#
# [200 rows x 2 columns]

# %%
rows_to_delete = [0]
population2_df.drop(rows_to_delete, inplace=True)

population2_df.head (200)
# Out:
#                               NAME DP05_0001E
# 1             Auburn city, Alabama      80009
# 2         Birmingham city, Alabama     196353
# 3             Dothan city, Alabama      70524
# 4             Hoover city, Alabama      92427
# 5         Huntsville city, Alabama     222363
# ..                             ...        ...
# 196     Westminster city, Colorado     114539
# 197   Bridgeport city, Connecticut     148365
# 198      Danbury city, Connecticut      86971
# 199     Hartford city, Connecticut     120682
# 200  New Britain city, Connecticut      74408
#
# [200 rows x 2 columns]

# %%
new_column_names = ['City2', 'Total Population']


population2_df.columns = new_column_names

# %%
population2_df.head (200)
# Out:
#                              City2 Total Population
# 1             Auburn city, Alabama            80009
# 2         Birmingham city, Alabama           196353
# 3             Dothan city, Alabama            70524
# 4             Hoover city, Alabama            92427
# 5         Huntsville city, Alabama           222363
# ..                             ...              ...
# 196     Westminster city, Colorado           114539
# 197   Bridgeport city, Connecticut           148365
# 198      Danbury city, Connecticut            86971
# 199     Hartford city, Connecticut           120682
# 200  New Britain city, Connecticut            74408
#
# [200 rows x 2 columns]

# %%
population2_df[['City', 'State']] = population2_df['City2'].str.split(', ', n=1, expand=True)

population2_df = population2_df.drop('City2', axis=1)

# %%
population2_df.head (200)
# Out:
#     Total Population              City        State
# 1              80009       Auburn city      Alabama
# 2             196353   Birmingham city      Alabama
# 3              70524       Dothan city      Alabama
# 4              92427       Hoover city      Alabama
# 5             222363   Huntsville city      Alabama
# ..               ...               ...          ...
# 196           114539  Westminster city     Colorado
# 197           148365   Bridgeport city  Connecticut
# 198            86971      Danbury city  Connecticut
# 199           120682     Hartford city  Connecticut
# 200            74408  New Britain city  Connecticut
#
# [200 rows x 3 columns]

# %%
population2_df['City'] = population2_df['City'].str.replace(' city', '', case=False)


population2_df.head(200)
# Out:
#     Total Population         City        State
# 1              80009       Auburn      Alabama
# 2             196353   Birmingham      Alabama
# 3              70524       Dothan      Alabama
# 4              92427       Hoover      Alabama
# 5             222363   Huntsville      Alabama
# ..               ...          ...          ...
# 196           114539  Westminster     Colorado
# 197           148365   Bridgeport  Connecticut
# 198            86971      Danbury  Connecticut
# 199           120682     Hartford  Connecticut
# 200            74408  New Britain  Connecticut
#
# [200 rows x 3 columns]

# %%
population2_df = population2_df[['City', 'State', 'Total Population']]


population2_df.head(200)
# Out:
#             City        State Total Population
# 1         Auburn      Alabama            80009
# 2     Birmingham      Alabama           196353
# 3         Dothan      Alabama            70524
# 4         Hoover      Alabama            92427
# 5     Huntsville      Alabama           222363
# ..           ...          ...              ...
# 196  Westminster     Colorado           114539
# 197   Bridgeport  Connecticut           148365
# 198      Danbury  Connecticut            86971
# 199     Hartford  Connecticut           120682
# 200  New Britain  Connecticut            74408
#
# [200 rows x 3 columns]

# %%
csv_file_path = 'Census_Population_By_City.csv'


population2_df.to_csv(csv_file_path, index=False)
