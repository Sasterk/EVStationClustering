# %%
# Import required libraries and dependencies
import pandas as pd
import hvplot.pandas
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Read the CSV file from the Resources folder into a Pandas DataFrame
pop_df = pd.read_csv("Census_Population_By_City.csv", index_col="State")

# Review the DataFrame
pop_df.head()
# Out:
#                City  Total Population
# State
# Alabama      Auburn             80009
# Alabama  Birmingham            196353
# Alabama      Dothan             70524
# Alabama      Hoover             92427
# Alabama  Huntsville            222363

# %%
# Generate summary statistics
pop_df.describe()
# Out:
#        Total Population
# count      6.460000e+02
# mean       1.911530e+05
# std        4.176111e+05
# min        6.399100e+04
# 25%        7.930425e+04
# 50%        1.049325e+05
# 75%        1.692608e+05
# max        8.335897e+06

# %%
# Plot your data to see what's in your DataFrame
pop_df.hvplot.line(
    width=800,
    height=400,
    rot=90
)
# Out:
# :Curve   [State]   (Total Population)

# %%
# Use the `StandardScaler()` module from scikit-learn to normalize the data from the CSV file
pop_data_scaled = StandardScaler().fit_transform(
    pop_df[["Total Population"]]
)

# %%
# Create a DataFrame with the scaled data
pop_data_scaled = pd.DataFrame(
    pop_df,
    columns=["Total Population"]
)

# Copy the crypto names from the original data
pop_data_scaled["State"] = pop_df.index

# Set the coinid column as index
pop_data_scaled = pop_data_scaled.set_index("State")

# Display sample data
pop_data_scaled.head()
# Out:
#          Total Population
# State
# Alabama             80009
# Alabama            196353
# Alabama             70524
# Alabama             92427
# Alabama            222363

# %%
# Create a list with the number of k-values from 1 to 11
k = list(range(1, 11))

# %%
# Create an empty list to store the inertia values
inertia = []

# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using `df_market_data_scaled`
# 3. Append the model.inertia_ to the inertia list

for i in k:
    k_model = KMeans(n_clusters=i, random_state=0)
    k_model.fit(pop_data_scaled)
    inertia.append(k_model.inertia_)
# Out:
# C:\Users\logan\OneDrive\New folder\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\logan\OneDrive\New folder\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\logan\OneDrive\New folder\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\logan\OneDrive\New folder\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\logan\OneDrive\New folder\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\logan\OneDrive\New folder\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\logan\OneDrive\New folder\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\logan\OneDrive\New folder\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\logan\OneDrive\New folder\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\logan\OneDrive\New folder\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\logan\OneDrive\New folder\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\logan\OneDrive\New folder\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\logan\OneDrive\New folder\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\logan\OneDrive\New folder\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\logan\OneDrive\New folder\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\logan\OneDrive\New folder\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\logan\OneDrive\New folder\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\logan\OneDrive\New folder\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\logan\OneDrive\New folder\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\logan\OneDrive\New folder\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(

# %%
# Create a dictionary with the data to plot the Elbow curve
elbow_data = {"k": k, "inertia": inertia}

# Create a DataFrame with the data to plot the Elbow curve
df_elbow = pd.DataFrame(elbow_data)

# Review the DataFrame
df_elbow.head()
# Out:
#    k       inertia
# 0  1  1.124874e+14
# 1  2  4.513349e+13
# 2  3  1.858993e+13
# 3  4  8.186160e+12
# 4  5  4.828371e+12

# %%
# Plot a line chart with all the inertia values computed with 
# the different values of k to visually identify the optimal value for k.
df_elbow.hvplot.line(
    x="k", 
    y="inertia", 
    title="Elbow Curve", 
    xticks=k
)
# Out:
# :Curve   [k]   (inertia)

# %%
# Initialize the K-Means model using the best value for k
model = KMeans(n_clusters=4, random_state=1)

# %%
# Fit the K-Means model using the scaled data
model.fit(pop_data_scaled)
# Out:
# C:\Users\logan\OneDrive\New folder\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\logan\OneDrive\New folder\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# KMeans(n_clusters=4, random_state=1)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled data
k_4 = model.predict(pop_data_scaled)

# Print the resulting array of cluster values.
print(k_4)
# Out:
# [2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 0 2 0 2 2 2 2 2 0 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 0 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 0 1 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 0 2 2 2 0 0 0 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 0 2
#  0 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 0 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 1 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 0 2
#  2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 0 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 0 2 2 2
#  2 2 2 2 2 2 0 2 2 0 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 0 2 2 2 2 2
#  2 2 2 3 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2
#  2 0 2 2 2 2 2 2 2 0 2 2 2 2 0 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 0
#  2 0 2 2 2 2 2 0 2 2 2 2 2 2 2 2 2 0 2 2 0 2 0 2 2 2 2 2 1 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2 2 2 2 2 2 0 2 2 2 2 2 2
#  2 2 2 2 2 2 0 2 2 2 2 2 2 2 2 2 2]

# %%
# Create a copy of the DataFrame
predictions_df = pop_data_scaled.copy()

# %%
# Add a new column to the DataFrame with the predicted clusters
predictions_df["predicted_cluster"] = k_4

# Display sample data
predictions_df.head()
# Out:
#          Total Population  predicted_cluster
# State
# Alabama             80009                  2
# Alabama            196353                  2
# Alabama             70524                  2
# Alabama             92427                  2
# Alabama            222363                  2

# %%
# Create a scatter plot using hvPlot by setting 
# `x="price_change_percentage_24h"` and `y="price_change_percentage_7d"`. 
# Color the graph points with the labels found using K-Means and 
# add the crypto name in the `hover_cols` parameter to identify 
# the cryptocurrency represented by each data point.

predictions_df.hvplot.scatter(
    x="Total Population",
    y="State",
    by="predicted_cluster",
    hover_cols="City"
)
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# Cell In[31], line 7
#       1 # Create a scatter plot using hvPlot by setting
#       2 # `x="price_change_percentage_24h"` and `y="price_change_percentage_7d"`.
#       3 # Color the graph points with the labels found using K-Means and
#       4 # add the crypto name in the `hover_cols` parameter to identify
#       5 # the cryptocurrency represented by each data point.
# ----> 7 predictions_df.hvplot.scatter(
#       8     x="Total Population",
#       9     y="State",
#      10     by="predicted_cluster",
#      11     hover_cols="City"
#      12 )
#
# File ~\OneDrive\New folder\envs\dev\lib\site-packages\hvplot\plotting\core.py:530, in hvPlotTabular.scatter(self, x, y, **kwds)
#     425 def scatter(self, x=None, y=None, **kwds):
#     426     """
#     427     The `scatter` plot visualizes your points as markers in 2D space. You can visualize
#     428     one more dimension by using colors.
#    (...)
#     528     - Wiki: https://en.wikipedia.org/wiki/Scatter_plot
#     529     """
# --> 530     return self(x, y, kind="scatter", **kwds)
#
# File ~\OneDrive\New folder\envs\dev\lib\site-packages\hvplot\plotting\core.py:92, in hvPlotBase.__call__(self, x, y, kind, **kwds)
#      89         plot = self._get_converter(x, y, kind, **kwds)(kind, x, y)
#      90         return pn.panel(plot, **panel_dict)
# ---> 92 return self._get_converter(x, y, kind, **kwds)(kind, x, y)
#
# File ~\OneDrive\New folder\envs\dev\lib\site-packages\hvplot\converter.py:1249, in HoloViewsConverter.__call__(self, kind, x, y)
#    1247                 dataset = Dataset(data)
#    1248             dataset = dataset.redim(**self._redim)
# -> 1249         obj = method(x, y)
#    1250         obj._dataset = dataset
#    1252 if self.crs and self.project:
#    1253     # Apply projection before rasterizing
#
# File ~\OneDrive\New folder\envs\dev\lib\site-packages\hvplot\converter.py:1662, in HoloViewsConverter.scatter(self, x, y, data)
#    1660 def scatter(self, x=None, y=None, data=None):
#    1661     self._error_if_unavailable('scatter')
# -> 1662     return self.chart(Scatter, x, y, data)
#
# File ~\OneDrive\New folder\envs\dev\lib\site-packages\hvplot\converter.py:1620, in HoloViewsConverter.chart(self, element, x, y, data)
#    1618 data, x, y = self._process_chart_args(data, x, y)
#    1619 if x and y and not isinstance(y, (list, tuple)):
# -> 1620     return self.single_chart(element, x, y, data)
#    1621 elif x and y and len(y) == 1:
#    1622     return self.single_chart(element, x, y[0], data)
#
# File ~\OneDrive\New folder\envs\dev\lib\site-packages\hvplot\converter.py:1538, in HoloViewsConverter.single_chart(self, element, x, y, data)
#    1532             data = data.reset_index()
#    1533         return (element(data, ([x] if x else [])+self.by, ys)
#    1534                 .relabel(**self._relabel)
#    1535                 .redim(**self._redim)
#    1536                 .opts(cur_opts, backend='bokeh')
#    1537                 .opts(compat_opts, backend=self._backend_compat))
# -> 1538     chart = Dataset(data, self.by+kdims, vdims).to(
#    1539         element, kdims, vdims, self.by).relabel(**self._relabel)
#    1540     chart = chart.layout() if self.subplots else chart.overlay(sort=False)
#    1541 else:
#
# File ~\OneDrive\New folder\envs\dev\lib\site-packages\holoviews\core\data\__init__.py:335, in Dataset.__init__(self, data, kdims, vdims, **kwargs)
#     333 (data, self.interface, dims, extra_kws) = initialized
#     334 super().__init__(data, **dict(kwargs, **dict(dims, **extra_kws)))
# --> 335 self.interface.validate(self, validate_vdims)
#     337 # Handle _pipeline property
#     338 if input_pipeline is None:
#
# File ~\OneDrive\New folder\envs\dev\lib\site-packages\holoviews\core\data\pandas.py:168, in PandasInterface.validate(cls, dataset, vdims)
#     166 not_found = [d for d in dimensions if d not in cols]
#     167 if not_found:
# --> 168     raise DataError("Supplied data does not contain specified "
#     169                     "dimensions, the following dimensions were "
#     170                     "not found: %s" % repr(not_found), cls)
#
# DataError: Supplied data does not contain specified dimensions, the following dimensions were not found: ['State']
#
# PandasInterface expects tabular data, for more information on supported datatypes see http://holoviews.org/user_guide/Tabular_Datasets.html
